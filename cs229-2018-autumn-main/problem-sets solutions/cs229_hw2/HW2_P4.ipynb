# %% [markdown]
# 4 a)
#
# $K$ is a valid kernel. Since the positive linear combination of symmetric and PSD matrices is symmetric and PSD, $K(x^{(i)},x^{(j)})=K_1(x^{(i)},x^{(j)})+K_2(x^{(i)},x^{(j)})$ is symmetric and PSD.
#
# 4 b)
#
# $K$ is not necessarily a kernel. Consider $K_2=2K_1$, then $K(x,z)=-K_1(x,z)$ and $K(x^{(i)},x^{(j)})=-K_1(x^{(i)},x^{(j)})$ is negative semi-definite.
#
# 4 c)
#
# $K$ is a valid kernel since the positive linear combination of symmetric and PSD matrices is symmetric and PSD.
#
# 4 d)
#
# $K$ is not a valid kernel since $K(x^{(i)},x^{(j)})=-aK1(x^{(i)},x^{(j)})$ is negative semi-definite.
#
# 4 e)
#
# $K$ is a valid kernel. By Cholesky decomposition, $(K_1)_{ij}=L_{ki}L_{kj}$ and $(K_2)_{ij}=S_{ki}S_{kj}$. So, $(K_1)_{ij}(K_2)_{ij}=L_{ki}L_{kj}S_{li}S_{lj}=T_{(k,l),i}T_{(k,l),j}$ where $T_{(k,l),i}=L_{ki}S_{li}$. So, $K$ is also symmetric and positive definite.
#
# 4 f)
#
# $K$ is a valid kernel by Cholesky decomposition.
#
# 4 g)
#
# $K$ is a valid kernel because $K_3$ is symmetric and PSD.
#
#
# 4 h)
#
# $K$ is a valid kernel because $p(K)$ is the positive linear combination of nonnegative powers of $K$, which preserves symmetry and PSD by part a), c), and e).
