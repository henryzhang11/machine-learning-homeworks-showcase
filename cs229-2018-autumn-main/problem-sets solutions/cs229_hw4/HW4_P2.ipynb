# %% [markdown]
# 2 a)
#
# If $\hat{\pi}_0=\pi_0$, then $E_{s\sim p(s),a\sim \pi_0(s,a)}\frac{\pi_1(s,a)}{\hat{\pi}_0(s,a)}R(s,a)=E_{s\sim p(s)}E_{a\sim\pi_0(s,a)}\frac{\pi_1(s,a)}{\hat{\pi}_0(s,a)}R(s,a)=E_{s\sim p(s)}\sum_{a}\pi_1(s,a)R(s,a)=E_{s\sim p(s)}E_{a\sim \pi_1(s,a)}R(s,a)=E_{s\sim p(s), a\sim\pi_1(s,a)}R(s,a)$.
#
# 2 b)
#
# If $\hat{\pi}_0=\pi_0$, then $E_{s\sim p(s), a\sim\pi_0(s,a)}\frac{\pi_1(s,a)}{\hat{\pi}_0(s,a)}R(s,a)/(E_{s\sim p(s),a\sim\pi_0(s,a)}\frac{\pi_1(s,a)}{\hat{\pi}_0(s,a)})=E_{s\sim p(s), a\sim\pi_0(s,a)}\frac{\pi_1(s,a)}{\hat{\pi}_0(s,a)}R(s,a)=E_{s\sim p(s)}\sum_a \pi_1(s,a) R(s,a)=E_{s\sim p(s), a\sim \pi_1(s,a)}R(s,a)$.
#
# 2 c)
#
# In the case that there is only a single data element $(s,a,R(s,a))$, $p(s)=1$, $\pi_0(s,a)=1$, the estimator equals $\pi_1(s,a)R(s,a)/\pi_1(s,a)=R(s,a)$. $E_{s\sim p(s),a\sim \pi(s,a)}R(s,a)\neq E_{s\sim p(s),a\sim \pi_1(s,a)}R(s,a)$.
#
# 2 d)
#
# When $\hat{\pi}_0=\pi_0$, doubly robust estimator equals $E_{s\sim p(s)}(E_{a\sim\pi_1(s,a)}\hat{R}(s,a))+ E_{s\sim p(s),a\sim \pi_0(s,a)}\frac{\pi_1(s,a)}{\hat{\pi}_0(s,a)}(R(s,a)-\hat{R}(s,a))=E_{s\sim p(s),a\sim\pi_1(s,a)}\hat{R}(s,a)+E_{s\sim p(s),a\sim \pi_1(s,a)}(R(s,a)-\hat{R}(s,a))=E_{s\sim p(s),a\sim\pi_1(s,a)}R(s,a)$.
#
# When $\hat{R}(s,a)=R(s,a)$, doubly robust estimator equals $E_{s\sim p(s)}(E_{a\sim \pi_1(s,a)}R(s,a))=E_{s\sim p(s),a\sim \pi_1(s,a)}R(s,a)$.
#
# 2 e)
#
# i) The regression estimator would work better because it estimates $R(s,a)$ more accurately.
#
# ii) The importance sampling estimator would work better because it accounts for the selection bias by reweighting the samples.
